# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout,Input

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("LP-IV-datasets/ECGdataset_Ass4/ecg_autoencoder_dataset.csv",header=None)

# %%
df
# Out:
#            0         1         2         3    ...       137       138       139  140
# 0    -0.112522 -2.827204 -3.773897 -4.349751  ...  0.123431  0.925286  0.193137    1
# 1    -1.100878 -3.996840 -4.285843 -4.506579  ...  0.773820  1.119621 -1.436250    1
# 2    -0.567088 -2.593450 -3.874230 -4.584095  ...  0.321097  0.904227 -0.421797    1
# 3     0.490473 -1.914407 -3.616364 -4.318823  ...  1.086798  1.403011 -0.383564    1
# 4     0.800232 -0.874252 -2.384761 -3.973292  ...  0.971020  1.614392  1.421456    1
# ...        ...       ...       ...       ...  ...       ...       ...       ...  ...
# 4993  0.608558 -0.335651 -0.990948 -1.784153  ...  1.688542  1.629593  1.342651    0
# 4994 -2.060402 -2.860116 -3.405074 -3.748719  ...  1.696818  1.483832  1.047612    0
# 4995 -1.122969 -2.252925 -2.867628 -3.358605  ... -2.874136 -2.008369 -1.808334    0
# 4996 -0.547705 -1.889545 -2.839779 -3.457912  ...  1.261335  1.150449  0.804932    0
# ...

# %%
x=df.drop([140],axis=1)
y=df[140]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=52)

# %%
input_dim=x_train.shape[1]
encoder=Sequential([
    Input(shape=(input_dim,)),
    Dense(8,activation='relu'),
    Dense(16,activation='relu')
])

decoder=Sequential([
    Input(shape=(16,)),
    Dense(8,activation='relu'),
    Dense(input_dim,activation='relu')
])

autoen=Sequential([
    encoder,
    decoder
])

# %%
autoen.compile(optimizer='adam',loss='mean_squared_error')
autoen.fit(x_train,x_train,epochs=50,batch_size=64, validation_data=(x_test,x_test))
# Out:
# Epoch 1/50
# 63/63 [==============================] - 1s 8ms/step - loss: 0.9468 - val_loss: 0.8695
# Epoch 2/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.8302 - val_loss: 0.8125
# Epoch 3/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.8029 - val_loss: 0.7920
# Epoch 4/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.7840 - val_loss: 0.7791
# Epoch 5/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.7750 - val_loss: 0.7702
# Epoch 6/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.7664 - val_loss: 0.7619
# Epoch 7/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.7603 - val_loss: 0.7572
# Epoch 8/50
# 63/63 [==============================] - 0s 4ms/step - loss: 0.7561 - val_loss: 0.7534
# Epoch 9/50
# 63/63 [==============================] - 0s 4ms/step - loss: 0.7530 - val_loss: 0.7500
# Epoch 10/50
# ...

# %%
y_pred=autoen.predict(x_test)

mse=np.mean(np.power(x_test-y_pred,2),axis=1)
threshold=np.percentile(mse,95)
outliers=mse>threshold
# Out:
# 32/32 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import confusion_matrix,classification_report

print("confusion matrix: \n", confusion_matrix(y_test,outliers))
# Out:
# confusion matrix:
#  [[382  46]
#  [568   4]]

# %%
num_anomalies=np.sum(y_test[outliers]==1)

print("outliers: ",np.sum(outliers))
print("anomalies: ", num_anomalies)
# Out:
# outliers:  50
# anomalies:  4

# %%
plt.plot(mse,marker='o',linestyle=' ',color='b')
plt.axhline(threshold,linestyle='--',color='r')
